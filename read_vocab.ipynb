# %%
import os
import torch

data = 'data/json_feat_2.1.0'
pp_folder = 'pp'

vocab = torch.load(os.path.join(data, "%s.vocab" % pp_folder))
print(vocab)
print(vocab['word'])
print(vocab['action_low'])
print(vocab['action_high'])
# Out:
# {'word': Vocab(2360), 'action_low': Vocab(15), 'action_high': Vocab(93)}
# Vocab(2360)
# Vocab(15)
# Vocab(93)

# %%
print(vocab['action_low'].word2index('<<stop>>'))
action_low = vocab['action_low']
# print(action_low.to_dict())
action_high = vocab['action_high']
print(action_high.to_dict())
word = vocab['word']
print(word.to_dict())
# Out:
# 2
# ...
